# %%
from tensorflow.python.summary.summary_iterator import summary_iterator

# %%
path = '1/logs/events.out.tfevents.1620962225.sh03-12n12.int.118710.123.v2'
for e in summary_iterator(path):
    print(e)
# Out:
# wall_time: 1620962225.0
# file_version: "brain.Event:2"
#
# wall_time: 1620962227.399968
# summary {
#   value {
#     tag: "Transition/G Loss 3"
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       tensor_content: "\000\000\000\000"
#     }
#     metadata {
#       plugin_data {
#         plugin_name: "scalars"
#       }
#     }
#   }
# }
#
# wall_time: 1620962227.40112
# summary {
#   value {
#     tag: "Transition/D Loss 3"
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       tensor_content: "\000\000\000\000"
#     }
#     metadata {
#       plugin_data {
#         plugin_name: "scalars"
#       }
#     }
#   }
# }
#
# wall_time: 1620962227.485646
# summary {
#   value {
#     tag: "Transition/G Loss 3"
#     tensor {
#       dtype: DT_FLOAT
#       tensor_shape {
#       }
#       tensor_content: "\000\000\000\000"
#     }
#     metadata {
#       plugin_data {
#         plugin_name: "scalars"
#       }
#     }
#   }
# }
#
# ...
